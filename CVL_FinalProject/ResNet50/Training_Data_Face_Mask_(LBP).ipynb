# %% [markdown]
# # Import Library

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Dataset

# %%
def load_image(image_path):
    image = cv2.imread(image_path)
    if image is None:
        print('Error: Could not load image.')
        return None, None

    gray = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
    return image, gray

# %% [markdown]
# # Feature Extraction

# %%
from skimage.feature import hog

# HOG / image params
ORIENTATIONS = 9
PIXELS_PER_CELL = (8, 8)
CELLS_PER_BLOCK = (2, 2)

def extract_hog_features(image_gray):
    """
    Ekstrak fitur HOG dari gambar grayscale (sudah di-resize).
    Output: vektor HOG.
    """
    features, hog_maps = hog(
        image_gray,
        orientations=ORIENTATIONS,
        pixels_per_cell=PIXELS_PER_CELL,
        cells_per_block=CELLS_PER_BLOCK,
        block_norm='L2-Hys',
        visualize=True,
        feature_vector=True
    )
    return features, hog_maps

# %%
from skimage.feature import local_binary_pattern
import numpy as np

# Parameter LBP
LBP_P = 8      # jumlah sampling points
LBP_R = 1      # radius
LBP_METHOD = "uniform"   # 'default', 'ror', 'uniform', 'var'


def extract_lbp_features(image_gray):
    """
    Ekstrak fitur LBP dari gambar grayscale (sudah di-resize).
    Output:
        - feature_vector: histogram LBP sebagai vektor fitur
        - lbp_map: peta LBP (untuk visualisasi)
    """

    # Step 1: Hitung LBP map
    lbp_map = local_binary_pattern(
        image_gray,
        P=LBP_P,
        R=LBP_R,
        method=LBP_METHOD
    )

    # Step 2: Konversi LBP map → Histogram (fitur numerik)
    # jumlah bin untuk uniform LBP = P + 2
    n_bins = LBP_P + 2

    hist, _ = np.histogram(
        lbp_map.ravel(),
        bins=n_bins,
        range=(0, n_bins),
        density=True
    )

    # hist = vektor fitur (panjang kecil, contoh: 10)
    return hist, lbp_map

# %% [markdown]
# # Pre-processing Dataset

# %%
def crop_half_image(img, bottom=True):
    """
    Mengembalikan crop separuh bawah (bottom=True) atau separuh atas (bottom=False)
    img: grayscale atau BGR numpy array
    """
    h = img.shape[0]
    mid = h // 2
    if bottom:
        cropped = img[mid:, :]
    else:
        cropped = img[:mid, :]
    return cropped

# %%
dataset_dir = '/content/drive/MyDrive/Colab Notebooks/Klasifikasi/dataset/'
IMAGE_SIZE = (64,64)
X = []
y = []
lbp_img =[]

for root, dirs, files in os.walk(dataset_dir):
    print(root, dirs, files)
    for f in files:
        _, image_gray = load_image(os.path.join(root, f))
        img_crop = crop_half_image(image_gray, bottom=True)
        # jika crop menghasilkan area kosong atau sangat kecil, fallback ke citra penuh
        if img_crop is None or img_crop.size == 0 or img_crop.shape[0] < 4 or img_crop.shape[1] < 4:
            img_crop = image_gray  # fallback
            # optional: print warning
            print(f"[WARN] Crop menghasilkan area kecil untuk {files}, menggunakan citra penuh.")

        roi_resized = cv2.resize(img_crop, IMAGE_SIZE, interpolation=cv2.INTER_AREA) # type: ignore
        lbp_feature, lbp_maps = extract_lbp_features(roi_resized)
        if lbp_feature is None:
            continue

        lbp_img.append(lbp_maps)
        X.append(lbp_feature)

        if root.split('/')[-1]=="without_mask":
            y.append(0)

        else:
            y.append(1)

X = np.array(X)
y = np.array(y)

print(f"[INFO] Total sampel fitur: {X.shape[0]}, dimensi fitur: {X.shape[1]}")
# Out:
# /content/drive/MyDrive/Colab Notebooks/Klasifikasi/dataset/ ['with_mask', 'without_mask'] []
# /content/drive/MyDrive/Colab Notebooks/Klasifikasi/dataset/with_mask [] ['0_0_1 copy 40.jpg', '0_0_2 copy 43.jpg', '0_0_1 copy 28.jpg', '0_0_5 copy 11.jpg', '0_0_1 copy 3.jpg', '0_0_5 copy 18.jpg', '0_0_0 copy 68.jpg', '0_0_2 copy 34.jpg', '0_0_2 copy 3.jpg', '0_0_2 copy.jpg', '0_0_0 copy 30.jpg', '0_0_0 copy 36.jpg', '0_0_1 copy 11.jpg', '0_0_1.png', '0_0_0 copy 23.jpg', '0_0_1 copy 22.jpg', '0_0_0 copy 2 2.jpg', '0_0_1 copy 2.jpg', '0_0_2 copy 16.jpg', '0_0_0 copy 20.jpg', '0_0_1 copy 9.jpg', '0_0_0 copy 74.jpg', '0_0_0 copy 19.jpg', '0_0_1 copy 23.jpg', '0_0_5 copy 7.jpg', '0_0_2 copy 31.jpg', '0_0_1 copy 19.jpg', '0_0_0 copy 6.jpg', '0_0_0 copy 29.jpg', '0_0_1 copy 32.jpg', '0_0_2 copy 11.jpg', '0_0_0.jpeg', '0_0_0 copy 9.jpg', '0_0_1 copy 16.jpg', '0_0_1 copy 36.jpg', '0_0_1 copy 20.jpg', '0_0_2.JPEG', '0_0_0 copy 65.jpg', '0_0_0 copy 57.jpg', '0_0_0 copy 5.jpg', '0_0_1 copy 46.jpg', '0_0_0 copy 45.jpg', '0_0_5 copy 23.jpg', '0_0_1 copy 30.jpg', '0_0_1 copy 17.jpg', '0_0_0 copy 77.jpg', '0_0_2 copy 17.jpg', '0_0_0 copy 42.jpg', '0_0_1 copy 12.jpg', '0_0_0 copy 50.jpg', '0_0_0 copy 62.jpg', '0_0_0 copy 44.jpg', '0_0_2 copy 40.jpg', '0_0_0 copy 69.jpg', '0_0_1.jpg', '0_0_0 copy 11.jpg', '0_0_5 copy 10.jpg', '0_0_2 copy 9.jpg', '0_0_2 copy 10.jpg', '0_0_2 copy 33.jpg', '0_0_0 copy.jpg', '0_0_1 copy 15.jpg', '0_0_0 copy.jpeg', '0_0_0 copy 60.jpg', '0_0_2 copy 20.jpg', '0_0_0 copy 37.jpg', '0_0_1 copy 34.jpg', '0_0_2 copy 24.jpg', '0_0_1 copy 38.jpg', '0_0_2 copy 7.jpg', '0_0_1 copy 8.jpg', '0_0_0 copy 24.jpg', '0_0_5 copy 19.jpg', '0_0_2 copy 21.jpg', '0_0_1 copy 37.jpg', '0_0_0 copy 22.jpg', '0_0_1 copy 5.jpg', '0_0_1 copy 14.jpg', '0_0_1 copy 27.jpg', '0_0_1 copy.JPEG', '0_0_0 copy 17.jpg', '0_0_0 copy 78.jpg', '0_0_1 copy 31.jpg', '0_0_0 copy 46.jpg', '0_0_2 copy 15.jpg', '0_0_1 copy 21.jpg', '0_0_0.jpg', '0_0_2 copy 13.jpg', '0_0_2 copy 12.jpg', '0_0_0 copy 70.jpg', '0_0_0 copy 53.jpg', '0_0_0 copy 8.jpg', '0_0_5 copy 20.jpg', '0_0_2 copy 46.jpg', '0_0_2 copy 6.jpg', '0_0_0 copy 28.jpg', '0_0_2 copy 25.jpg', '0_0_0 copy 35.jpg', '0_0_5 copy 17.jpg', '0_0_0 copy 2.png', '0_0_5 copy 13.jpg', '0_0_0 copy 15.jpg', '0_0_5 copy 25.jpg', '0_0_2 copy 28.jpg', '0_0_1 copy 42.jpg', '0_0_0 copy 16.jpg', '0_0_0 copy 27.jpg', '0_0_1 copy 33.jpg', '0_0_1 copy 35.jpg', '0_0_0 copy 61.jpg', '0_0_0 copy 55.jpg', '0_0_1 copy 44.jpg', '0_0_1 copy 48.jpg', '0_0_1 copy 18.jpg', '0_0_2 copy 22.jpg', '0_0_2 copy 36.jpg', '0_0_5 copy 22.jpg', '0_0_0 copy 31.jpg', '0_0_0 copy 14.jpg', '0_0_1 copy 41.jpg', '0_0_0 copy 34.jpg', '0_0_0 copy 41.jpg', '0_0_0 copy 25.jpg', '0_0_0 copy 33.jpg', '0_0_0 copy 10.jpg', '0_0_0 copy 56.jpg', '0_0_1 copy 43.jpg', '0_0_0 copy 13.jpg', '0_0_0 copy 3 2.jpg', '0_0_0 copy 47.jpg', '0_0_0 copy 40.jpg', '0_0_0 copy 71.jpg', '0_0_0 copy 59.jpg', '0_0_0.png', '0_0_2 copy 14.jpg', '0_0_0 copy 54.jpg', '0_0_5 copy 24.jpg', '0_0_1 copy 29.jpg', '0_0_2 copy 5.jpg', '0_0_0 copy 48.jpg', '0_0_0 copy 97.jpg', '0_0_2 copy 30.jpg', '0_0_0 copy 3.png', '0_0_2 copy 19.jpg', '0_0_0 copy 21.jpg', '0_0_2 copy 18.jpg', '0_0_1 copy 51.jpg', '0_0_5 copy 14.jpg', '0_0_0 copy 63.jpg', '0_0_5 copy 6.jpg', '0_0_0 copy 7.jpg', '0_0_2 copy 8.jpg', '0_0_0 copy 5 2.jpg', '0_0_2 copy 26.jpg', '0_0_1 copy 45.jpg', '0_0_0 copy 32.jpg', '0_0_1 copy 50.jpg', '0_0_0 copy 4.jpg', '0_0_5 copy 21.jpg', '0_0_1 copy 49.jpg', '0_0_1 copy 10.jpg', '0_0_0 copy 52.jpg', '0_0_1 copy 13.jpg', '0_0_0 copy 73.jpg', '0_0_0 copy 43.jpg', '0_0_0 copy 75.jpg', '0_0_0 copy 38.jpg', '0_0_0 copy 58.jpg', '0_0_0 copy.png', '0_0_2 copy 35.jpg', '0_0_2 copy 45.jpg', '0_0_1 copy 24.jpg', '0_0_0 copy 26.jpg', '0_0_0 copy 12.jpg', '0_0_0 copy 66.jpg', '0_0_1 copy 7.jpg', '0_0_2 copy 4.jpg', '0_0_0 copy 67.jpg', '0_0_2 copy 23.jpg', '0_0_1 copy 26.jpg', '0_0_5 copy 15.jpg', '0_0_0 copy 3.jpg', '0_0_0 copy 4 2.jpg', '0_0_1 copy 25.jpg', '0_0_2 copy 32.jpg', '0_0_1 copy 4.jpg', '0_0_1 copy 39.jpg', '0_0_2 copy 39.jpg', '0_0_0 copy 76.jpg', '0_0_0 copy 2.jpg', '0_0_0 copy 72.jpg ...
# /content/drive/MyDrive/Colab Notebooks/Klasifikasi/dataset/without_mask [] ['0_0_haiqing_0170.jpg', '0_0_guanyue_0040.jpg', '0_0_fengjianyu_0059.jpg', '0_0_chenhaomin_0117.jpg', '0_0_huangtingting_0008.jpg', '0_0_chenyao_0027.jpg', '0_0_chenyao_0013.jpg', '0_0_fanyichen_0049.jpg', '0_0_gulinazha_0038.jpg', '0_0_chenhuilin_0085.jpg', '0_0_hanxue_0088.jpg', '0_0_fanyichen_0053.jpg', '0_0_caizhuoyan_0029.jpg', '0_0_caiyilin_0051.jpg', '0_0_fanshiqi_0012.jpg', '0_0_benxi_0187.jpg', '0_0_hanxue_0085.jpg', '0_0_aidai_0029.jpg', '0_0_chenxiang_0070.jpg', '0_0_caizhuoyan_0017.jpg', '0_0_guanyue_0048.jpg', '0_0_huge_0061.jpg', '0_0_huge_0018.jpg', '0_0_chenhuilin_0018.jpg', '0_0_fengjianyu_0042.jpg', '0_0_chenyao_0063.jpg', '0_0_huangtingting_0035.jpg', '0_0_anhu_0056.jpg', '0_0_hanxue_0021.jpg', '0_0_fanyichen_0063.jpg', '0_0_baobeier_0016.jpg', '0_0_chenyao_0043.jpg', '0_0_huangjinglun_0008.jpg', '0_0_fanyichen_0011.jpg', '0_0_aidai_0074.jpg', '0_0_anhu_0189.jpg', '0_0_chenhuilin_0096.jpg', '0_0_fanyichen_0081.jpg', '0_0_baibaihe_0085.jpg', '0_0_caizhuoyan_0046.jpg', '0_0_benxi_0054.jpg', '0_0_fanyichen_0078.jpg', '0_0_fengjianyu_0072.jpg', '0_0_hanxue_0073.jpg', '0_0_fanyichen_0040.jpg', '0_0_dongchengpeng_0018.jpg', '0_0_dongchengpeng_0016.jpg', '0_0_gulinazha_0078.jpg', '0_0_caiyilin_0024.jpg', '0_0_huxia_0121.jpg', '0_0_caizhuoyan_0014.jpg', '0_0_chenxuedong_0074.jpg', '0_0_gulinazha_0172.jpg', '0_0_hanxue_0096.jpg', '0_0_baibaihe_0216.jpg', '0_0_huxia_0097.jpg', '0_0_chenyao_0065.jpg', '0_0_caiguoqing_0113.jpg', '0_0_chenhuilin_0114.jpg', '0_0_chenhaomin_0023.jpg', '0_0_chenyao_0074.jpg', '0_0_aidai_0084.jpg', '0_0_haiqing_0173.jpg', '0_0_chenxiang_0006.jpg', '0_0_baobeier_0046.jpg', '0_0_dongchengpeng_0020.jpg', '0_0_chenyao_0016.jpg', '0_0_fengjianyu_0036.jpg', '0_0_dongchengpeng_0042.jpg', '0_0_fanshiqi_0094.jpg', '0_0_chenhaomin_0053.jpg', '0_0_huangjinglun_0017.jpg', '0_0_anhu_0211.jpg', '0_0_fanshiqi_0029.jpg', '0_0_hanxue_0091.jpg', '0_0_fanshiqi_0002.jpg', '0_0_huge_0039.jpg', '0_0_gulinazha_0149.jpg', '0_0_anhu_0209.jpg', '0_0_anhu_0062.jpg', '0_0_caiguoqing_0007.jpg', '0_0_chenhuilin_0094.jpg', '0_0_chenhuilin_0104.jpg', '0_0_caiyilin_0029.jpg', '0_0_chenyao_0024.jpg', '0_0_fanyichen_0018.jpg', '0_0_anhu_0027.jpg', '0_0_dongchengpeng_0021.jpg', '0_0_baibaihe_0077.jpg', '0_0_fanyichen_0099.jpg', '0_0_jianailiang_0006.jpg', '0_0_baobeier_0064.jpg', '0_0_chenhe_0049.jpg', '0_0_chenyao_0053.jpg', '0_0_chenhuilin_0076.jpg', '0_0_fanyichen_0068.jpg', '0_0_chenyao_0038.jpg', '0_0_fanshiqi_0092.jpg', '0_0_chenglong_0063.jpg', '0_0_fanwei_0017.jpg', '0_0_benxi_0129.jpg', '0_0_guanyue_0011.jpg', '0_0_cengyongti_0063.jpg', '0_0_anhu_0098.jpg', '0_0_chenhuilin_0048.jpg', '0_0_chenyao_0044.jpg', '0_0_dongchengpeng_0005.jpg', '0_0_chenglong_0036.jpg', '0_0_anhu_0025.jpg', '0_0_caizhuoyan_0027.jpg', '0_0_caiyilin_0101.jpg', '0_0_cengyongti_0058.jpg', '0_0_caiyilin_0100.jpg', '0_0_caizhuoyan_0013.jpg', '0_0_jianailiang_0007.jpg', '0_0_chenxuedong_0050.jpg', '0_0_chenxiang_0005.jpg', '0_0_fanshiqi_0089.jpg', '0_0_fanyichen_0091.jpg', '0_0_chenyao_0033.jpg', '0_0_caizhuoyan_0041.jpg', '0_0_baibaihe_0204.jpg', '0_0_aidai_0014.jpg', '0_0_baobeier_0098.jpg', '0_0_changshilei_0182.jpg', '0_0_caizhuoyan_0065.jpg', '0_0_baobeier_0099.jpg', '0_0_huge_0045.jpg', '0_0_chenxuedong_0049.jpg', '0_0_caizhuoyan_0068.jpg', '0_0_gulinazha_0082.jpg', '0_0_huangtingting_0034.jpg', '0_0_chenyao_0051.jpg', '0_0_chenhaomin_0114.jpg', '0_0_huge_0029.jpg', '0_0_cengyongti_0087.jpg', '0_0_baobeier_0140.jpg', '0_0_cengyongti_0003.jpg', '0_0_huge_0019.jpg', '0_0_cengyongti_0016.jpg', '0_0_chenhe_0031.jpg', '0_0_baibaihe_0093.jpg', '0_0_caiguoqing_0146.jpg', '0_0_fanyichen_0029.jpg', '0_0_chenhuilin_0023.jpg', '0_0_baibaihe_0236.jpg', '0_0_caiguoqing_0093.jpg', '0_0_anhu_0157.jpg', '0_0_anhu_0057.jpg', '0_0_caiguoqing_0067.jpg', '0_0_chenxuedong_0070.jpg', '0_0_jianailiang_0005.jpg', '0_0_hanxue_0004.jpg', '0_0_caizhuoyan_0004.jpg', '0_0_hanxue_0062.jpg', '0_0_ce ...
# [INFO] Total sampel fitur: 400, dimensi fitur: 10

# %% [markdown]
# # Visualisasi Features

# %%
from skimage import exposure

ncol = 4
nrow = 8
fig, axes = plt.subplots(nrow, ncol, figsize=(10, 2.5*nrow),subplot_kw={'xticks':[], 'yticks':[]})
for i, ax in enumerate(axes.flat):
    if i < 16:
        temp = lbp_img[i]
        lbp_image = exposure.rescale_intensity(temp, in_range=(0, temp.max()))
        ax.imshow(lbp_image, cmap='gray')
        ax.set_title(f'LBP {i+1}')
    else:
        temp = lbp_img[len(lbp_img) - (i)]
        lbp_image = exposure.rescale_intensity(temp, in_range=(0, temp.max()))
        ax.imshow(lbp_image, cmap='gray')
        ax.set_title(f'LBP {len(lbp_img) - (i)}')

plt.tight_layout()
plt.show()

# %%
from sklearn.model_selection import train_test_split

TEST_SIZE = 0.2
RANDOM_STATE = 42

X_train, X_test, y_train, y_test = train_test_split(
        X, y,
        test_size=TEST_SIZE,
        random_state=RANDOM_STATE,
        stratify=y )

# %% [markdown]
# # Training Process

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix

# scale fitur
scaler = StandardScaler()
X_train_s = scaler.fit_transform(X_train)
X_test_s = scaler.transform(X_test)

# training SVM (RBF)
clf = SVC(kernel='rbf', probability=True, random_state=RANDOM_STATE)
print("[INFO] Training SVM...")
clf.fit(X_train_s, y_train)

# evaluasi
y_pred = clf.predict(X_test_s)
print("\n[RESULT] Classification report:")
print(classification_report(y_test, y_pred, target_names=["without_mask","with_mask"]))
print("Confusion matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# [INFO] Training SVM...
#
# [RESULT] Classification report:
#               precision    recall  f1-score   support
#
# without_mask       0.93      0.97      0.95        40
#    with_mask       0.97      0.93      0.95        40
#
#     accuracy                           0.95        80
#    macro avg       0.95      0.95      0.95        80
# weighted avg       0.95      0.95      0.95        80
#
# Confusion matrix:
# [[39  1]
#  [ 3 37]]

# %%
import joblib

MODEL_PATH = "svm_mask_200_bottom_half.pkl"

# simpan model + scaler
joblib.dump({"model": clf,
             "scaler": scaler,
             "config": {"image_size": IMAGE_SIZE,
                        "lbp_params": {"orientations": ORIENTATIONS,
                                       "pixels_per_cell": PIXELS_PER_CELL,
                                       "cells_per_block": CELLS_PER_BLOCK},
                                        "crop": "bottom" }}, MODEL_PATH)
print(f"[INFO] Model tersimpan di: {MODEL_PATH}")
# Out:
# [INFO] Model tersimpan di: svm_mask_200_bottom_half.pkl

# %% [markdown]
# # Test Single Image

# %% [markdown]
# ## 1. Face Detection

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
def detect_faces(image_gray, scale_factor=1.1, min_neighbors=5, min_size=(30, 30)):
    faces = face_cascade.detectMultiScale(
        image_gray,
        scaleFactor=scale_factor,
        minNeighbors=min_neighbors,
        minSize=min_size
  )
    return faces

# %%
def crop_faces(image_gray, faces, return_all=False):
    cropped_faces = []
    selected_faces = []
    if len(faces) > 0:
        if return_all:
            for x, y, w, h in faces:
                selected_faces.append((x, y, w, h))
                cropped_faces.append(image_gray[y:y+h, x:x+w])
        else:
            x, y, w, h = max(faces, key=lambda rect: rect[2] * rect[3])
            selected_faces.append((x, y, w, h))
            cropped_faces.append(image_gray[y:y+h, x:x+w])

    return cropped_faces, selected_faces

# %% [markdown]
# ## 2. Feature Extraction

# %%
def feature_extraction_for_test(image_gray):

    features, lbp_maps = [],[]

    faces = detect_faces(image_gray)

    cropped_face, _ = crop_faces(image_gray, faces)

    if cropped_face is None:
        print("wajah tidak terdeteksi..")
        return features, lbp_maps
    else:

        img_crop = crop_half_image(cropped_face[0], bottom=True)

        # jika crop menghasilkan area kosong atau sangat kecil, fallback ke citra penuh
        if img_crop is None or img_crop.size == 0 or img_crop.shape[0] < 4 or img_crop.shape[1] < 4:
            img_crop = cropped_face[0]  # fallback
            # optional: print warning
            print(f"[WARN] Crop menghasilkan area kecil untuk {files}, menggunakan citra penuh.")

        roi_resized = cv2.resize(img_crop, IMAGE_SIZE, interpolation=cv2.INTER_AREA) # type: ignore

        features, lbo_maps = extract_lbp_features(roi_resized)
        features = np.array(features)
        features = features.reshape(1, -1)
        return features, lbp_maps

# %% [markdown]
# ## 3. Prediction Process

# %%
import joblib

def predict_image(image, features, model_path):

    data = joblib.load(model_path)
    model_loaded = data.get("model")
    scaler = data.get("scaler")

    if scaler is not None:
        features = scaler.transform(features)
    pred = model_loaded.predict(features)[0]
    conf = None
    prob = 0
    prob = model_loaded.predict_proba(features)[0] if hasattr(model_loaded, "predict_proba") else None
    conf = float(max(prob))

    if pred == 1:
        label_str = "MASK"
    else:
        label_str = "NO MASK"

    print(f"Prediksi: {label_str}")

    return draw_result(image, conf, label_str)

def draw_text(image, label, score,
              font=cv2.FONT_HERSHEY_SIMPLEX,
              pos=(10, 30),
              font_scale=0.6,
              font_thickness=2,
              text_color=(255, 255, 255),
              text_color_bg=(0, 0, 255)
              ):
    x, y = pos
    score_text = f'Score: {score:.2f}'

    (w1, h1), _ = cv2.getTextSize(score_text, font, font_scale, font_thickness)
    (w2, h2), _ = cv2.getTextSize(label,      font, font_scale, font_thickness)

    box_width  = max(w1, w2) + 20
    box_height = h1 + h2 + 25

    # pastikan tidak keluar dari gambar (opsional)
    x = max(0, x)
    y = max(box_height, y)

    # background kotak
    cv2.rectangle(image,
                  (x, y - box_height),
                  (x + box_width, y),
                  text_color_bg,
                  -1)

    # tulis label
    cv2.putText(image, label, (x + 10, y - h1 - 10),
                font, font_scale, text_color, font_thickness)

    # tulis score
    cv2.putText(image, score_text, (x + 10, y - 10),
                font, font_scale, text_color, font_thickness)


def draw_result(image_bgr, score, label):
    """
    image_bgr : citra BGR (OpenCV)
    score     : float
    label     : string
    return    : citra BGR yang sudah diberi teks
    """
    result_image = image_bgr.copy()
    draw_text(result_image, label, score, pos=(10, 40))
    return result_image

# %%
TESTING_IMAGE = "/content/drive/MyDrive/Colab Notebooks/Klasifikasi/testing/mask1.png"

lbp_feature, lbp_maps = [],[]
image_rgb, image_gray = load_image(TESTING_IMAGE)

lbp_feature, lbp_image = feature_extraction_for_test(image_gray)

result_image = predict_image(image_rgb, lbp_feature, MODEL_PATH)

plt.imshow(result_image)
# Out:
# Prediksi: MASK

# %%
TESTING_IMAGE = "/content/drive/MyDrive/Colab Notebooks/Klasifikasi/testing/1.jpg"

lbp_feature, lbp_maps = [],[]
image_rgb, image_gray = load_image(TESTING_IMAGE)

lbp_feature, lbp_maps = feature_extraction_for_test(image_gray)

result_image = predict_image(image_rgb, lbp_feature, MODEL_PATH)

plt.imshow(result_image)
# Out:
# Prediksi: MASK
